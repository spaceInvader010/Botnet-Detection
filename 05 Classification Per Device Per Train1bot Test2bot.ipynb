# %%
# %matplotlib inline
import glob, os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd.options.display.max_rows = 200

plt.rcParams['figure.figsize'] = [20, 10]
plt.rc('font', size=20)

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ## IOT Devices
#
# The dataset has been extracted at `ROOT_PATH`, containing the data for each IOT device. There are 9 devices in total. There are folders for each IOT device containing `benign_traffic.csv` and further two folders for `gafgyt_attacks` and `mirai_attacks`

# %%
ROOT_PATH = r'C:\Users\jessm\Desktop\HonoursProject\N-BaIoT_Dataset'
IOT_DEVS = [ 'Danmini_Doorbell',
             #'Ecobee_Thermostat',
             #'Ennio_Doorbell',
             'B120N10_Baby_Mon',
             #'737E_Security_Cam',
             #'838_Security_Cam',
             #'Samsung_Webcam',
             '1002_Security_Cam',
             #'1003_Security_Cam'
           ]

# %% [markdown]
# ## Paths to CSVs
# We create a python dictionary that contains all the paths to the CSVs for the respective IOT devices

# %%
PATHS_DICT = {}

for i in IOT_DEVS:
    PATHS_DICT[i] = {}
    print('[' + i + ']')
    iot_dir = os.path.join(ROOT_PATH, i)
    PATHS_DICT[i]['benign'] = os.path.join(iot_dir, 'benign_traffic.csv')
    print('  ', 'benign_traffic.csv')
    attacks = [ d for d in os.listdir(iot_dir)
                   if os.path.isdir( os.path.join(iot_dir, d)) ]
    for attack in attacks:
        attack_name = attack.split('_')[0]
        
        PATHS_DICT[i][attack_name] = {}
        attack_dir = os.path.join(iot_dir, attack)
        types = [ f for f in os.listdir(attack_dir)
                   if os.path.isfile( os.path.join(attack_dir, f)) ]
        print('  ', attack_name, ': ', types)
        for t in types:
            type_name = t.split('.')[0]
            PATHS_DICT[i][attack_name][type_name] = os.path.join(attack_dir,t)
# Out:
# [Danmini_Doorbell]
#    benign_traffic.csv
#    gafgyt :  ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']
#    mirai :  ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']
# [Ecobee_Thermostat]
#    benign_traffic.csv
#    gafgyt :  ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']
#    mirai :  ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']
# [Philips_Baby_Monitor]
#    benign_traffic.csv
#    gafgyt :  ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']
#    mirai :  ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']
# [737E_Security_Cam]
#    benign_traffic.csv
#    gafgyt :  ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']
#    mirai :  ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']
# [838_Security_Cam]
#    benign_traffic.csv
#    gafgyt :  ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']
#    mirai :  ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']
# [1002_Security_Cam]
#    benign_traffic.csv
#    gafgyt :  ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']
#    mirai :  ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']
# [1003_Security_Cam]
#    benign_traffic.csv
#    gafgyt :  ['combo.csv', 'junk.csv', 'scan.csv', 'tcp.csv', 'udp.csv']
#    mirai :  ['ack.csv', 'scan.csv', 'syn.csv', 'udp.csv', 'udpplain.csv']

# %% [markdown]
# ## Loading CSVs into Pandas
# We will create pandas dataframe for each botnet attack on each IOT device. For each datafram we will combine the attack traffic with the benign traffic add the following two columns:
# - `traffic_type` : benign or attack (0 or 1)
# - `attack_type`  : type of attack e.g, ack, scan etc.

# %%
import pandas as pd

nbaiot_dict = {}

for iot_dev in PATHS_DICT:
    nbaiot_dict[iot_dev] = {}
    b_df = pd.read_csv(PATHS_DICT[iot_dev]['benign'])
    b_df['traffic_type'] = 'benign'
    b_df['attack_type'] = 'benign'

    for botnet in [b for b in PATHS_DICT[iot_dev] if b != 'benign']:
        nbaiot_dict[iot_dev][botnet] = pd.DataFrame()
        nbaiot_dict[iot_dev][botnet] = pd.concat([nbaiot_dict[iot_dev][botnet], b_df])

        for attack in PATHS_DICT[iot_dev][botnet]:
            a_df = pd.read_csv(PATHS_DICT[iot_dev][botnet][attack])
            a_df['traffic_type'] = 'attack'
            a_df['attack_type'] = attack
            nbaiot_dict[iot_dev][botnet] = pd.concat([nbaiot_dict[iot_dev][botnet], a_df])

# %%
for k in nbaiot_dict:
    print(k)
    for b in nbaiot_dict[k]:
        print('  ',b,':','<benign+attack>')
# Out:
# Danmini_Doorbell
#    gafgyt : <benign+attack>
#    mirai : <benign+attack>
# Ecobee_Thermostat
#    gafgyt : <benign+attack>
#    mirai : <benign+attack>
# Philips_Baby_Monitor
#    gafgyt : <benign+attack>
#    mirai : <benign+attack>
# 737E_Security_Cam
#    gafgyt : <benign+attack>
#    mirai : <benign+attack>
# 838_Security_Cam
#    gafgyt : <benign+attack>
#    mirai : <benign+attack>
# 1002_Security_Cam
#    gafgyt : <benign+attack>
#    mirai : <benign+attack>
# 1003_Security_Cam
#    gafgyt : <benign+attack>
#    mirai : <benign+attack>

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Pre processing
# Convert the target column `traffic_type` to integer 0 = benigh, 1 = attack

# %%
for dev in nbaiot_dict:
    for botnet in nbaiot_dict[dev]:
        nbaiot = nbaiot_dict[dev][botnet]

        nbaiot.loc[ nbaiot['traffic_type']=='attack','traffic_type' ]=1
        nbaiot.loc[ nbaiot['traffic_type']=='benign','traffic_type' ]=0
        nbaiot['traffic_type'] = nbaiot['traffic_type'].astype(int)
        
        nbaiot_dict[dev][botnet] = nbaiot

# %% [markdown]
# ### Classifiers and training functions

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
classfiers = {
    'KNN' : KNeighborsClassifier(),
    'RFR' : RandomForestClassifier(),
    'DTR' : DecisionTreeClassifier(),
    'ADB' : AdaBoostClassifier(),
    
}

# %% [markdown]
# ## Main Loop

# %%
all_results = [
    ['DEVICE', 'TRAIN-BOTNET', 'TEST-BOTNET', 'CLASSIFIER', 'ACCURACY', 'PRECISION', 'RECALL', 'F1-SCORE', 'FALSE-P', 'FALSE-N' ]
]

for clf_name in classfiers:
    clf = classfiers[clf_name]
    for dev in nbaiot_dict:
        if 'gafgyt' not in nbaiot_dict[dev] and 'gafgyt' not in nbaiot_dict[dev]:
            print('BOTNETS NOT FOUND, SKIPPING: ',dev)
            continue
        for trn_bot, tst_bot in [ ('gafgyt','mirai'), ('mirai','gafgyt')]:
            train_df = nbaiot_dict[dev][trn_bot]
            test_df = nbaiot_dict[dev][tst_bot]

            X_train = train_df.drop( ["attack_type", "traffic_type" ], axis=1 )
            y_train = train_df["traffic_type"]
            X_test = test_df.drop( ["attack_type", "traffic_type" ], axis=1 )
            y_test = test_df["traffic_type"]

            clf.fit(X_train, y_train)
            y_preds = clf.predict(X_test)

            clrp = classification_report(y_test, y_preds, output_dict=True)
            conf_mat = confusion_matrix(y_test, y_preds)
            fp = conf_mat[0][1]
            fn = conf_mat[1][0]
            result = [
                dev,
                trn_bot,
                tst_bot,
                clf_name,
                round(clrp['accuracy'],4),
                round(clrp['macro avg']['precision'],4),
                round(clrp['macro avg']['recall'],4),
                round(clrp['macro avg']['f1-score'],4),
                fp,
                fn
            ]
            print(result)
            all_results.append(result)
# Out:
# ['Danmini_Doorbell', 'gafgyt', 'mirai', 'KNN', 0.5817, 0.5719, 0.7739, 0.4808, 113, 293376]
# ['Danmini_Doorbell', 'mirai', 'gafgyt', 'KNN', 0.3731, 0.5873, 0.6357, 0.3663, 212, 229368]
# ['Ecobee_Thermostat', 'gafgyt', 'mirai', 'KNN', 0.5533, 0.5256, 0.7625, 0.401, 227, 234425]
# ['Ecobee_Thermostat', 'mirai', 'gafgyt', 'KNN', 0.3516, 0.5278, 0.6536, 0.2998, 234, 209684]
# ['Philips_Baby_Monitor', 'gafgyt', 'mirai', 'KNN', 0.5988, 0.6785, 0.7417, 0.5892, 55, 315246]
# ['Philips_Baby_Monitor', 'mirai', 'gafgyt', 'KNN', 0.5291, 0.6987, 0.6288, 0.514, 3044, 226720]
# ['737E_Security_Cam', 'gafgyt', 'mirai', 'KNN', 0.6729, 0.6377, 0.8124, 0.6013, 115, 162822]
# ['737E_Security_Cam', 'mirai', 'gafgyt', 'KNN', 0.4402, 0.607, 0.6634, 0.4311, 613, 218958]
# ['838_Security_Cam', 'gafgyt', 'mirai', 'KNN', 0.6655, 0.6784, 0.7934, 0.634, 246, 176339]
# ['838_Security_Cam', 'mirai', 'gafgyt', 'KNN', 0.4753, 0.6514, 0.6502, 0.4753, 1102, 212744]
# ['1002_Security_Cam', 'gafgyt', 'mirai', 'KNN', 0.4983, 0.5708, 0.7253, 0.4361, 110, 280732]
# ['1002_Security_Cam', 'mirai', 'gafgyt', 'KNN', 0.3926, 0.5877, 0.6467, 0.3825, 322, 212156]
# ['1003_Security_Cam', 'gafgyt', 'mirai', 'KNN', 0.4892, 0.5332, 0.7336, 0.3821, 55, 272895]
# ['1003_Security_Cam', 'mirai', 'gafgyt', 'KNN', 0.3693, 0.5414, 0.6623, 0.3259, 121, 211759]
# ['Danmini_Doorbell', 'gafgyt', 'mirai', 'RFR', 1.0, 1.0, 1.0, 1.0, 0, 0]
# ['Danmini_Doorbell', 'mirai', 'gafgyt', 'RFR', 0.4572, 0.5998, 0.6861, 0.4376, 0, 198780]
# ['Ecobee_Thermostat', 'gafgyt', 'mirai', 'RFR', 1.0, 0.9991, 1.0, 0.9995, 0, 24]
# ['Ecobee_Thermostat', 'mirai', 'gafgyt', 'RFR', 0.3825, 0.5308, 0.6782, 0.3208, 0, 199909]
# ['Philips_Baby_Monitor', 'gafgyt', 'mirai', 'RFR', 0.9049, 0.8505, 0.9388, 0.8795, 0, 74724]
# ['Philips_Baby_Monitor', 'mirai', 'gafgyt', 'RFR', 0.5805, 0.7306, 0.6727, 0.5723, 0, 204723]
# ['737E_Security_Cam', 'gafgyt', 'mirai', 'RFR', 1.0, 1.0, 1.0, 1.0, 0, 4]
# ['737E_Security_Cam', 'mirai', 'gafgyt', 'RFR', 0.4678, 0.6147, 0.6838, 0.4554, 0, 208751]
# ['838_Security_Cam', 'gafgyt', 'mirai', 'RFR', 0.9938, 0.9838, 0.9962, 0.9899, 0, 3292]
# ['838_Security_Cam', 'mirai', 'gafgyt', 'RFR', 0.5165, 0.6667, 0.6812, 0.516, 0, 197036]
# ['1002_Security_Cam', 'gafgyt', 'mirai', 'RFR', 0.9999, 0.9995, 1.0, 0.9997, 0, 50]
# ['1002_Security_Cam', 'mirai', 'gafgyt', 'RFR', 0.4479, 0.5972, 0.6815, 0.4291, 0, 193124]
# ['1003_Security_Cam', 'gafgyt', 'mirai', 'RFR', 0.952, 0.7162, 0.9751, 0.7891, 0, 25634]
# ['1003_Security_Cam', 'mirai', 'gafgyt', 'RFR', 0.4015, 0.5443, 0.6823, 0.3485, 0, 201066]
# ['Danmini_Doorbell', 'gafgyt', 'mirai', 'DTR', 0.9945, 0.9641, 0.9971, 0.9799, 0, 3829]
# ['Danmini_Doorbell', 'mirai', 'gafgyt', 'DTR', 0.4562, 0.5996, 0.6855, 0.4368, 0, 199147]
# ['Ecobee_Thermostat', 'gafgyt', 'mirai', 'DTR', 0.9626, 0.7001, 0.9808, 0.776, 0, 19653]
# ['Ecobee_Thermostat', 'mirai', 'gafgyt', 'DTR', 0.3821, 0.5308, 0.678, 0.3205, 0, 200033]
# ['Philips_Baby_Monitor', 'gafgyt', 'mirai', 'DTR', 0.9519, 0.9113, 0.9691, 0.9354, 0, 37801]
# ['Philips_Baby_Monitor', 'mirai', 'gafgyt', 'DTR', 0.5366, 0.7183, 0.6385, 0.5208, 0, 226115]
# ['737E_Security_Cam', 'gafgyt', 'mirai', 'DTR', 0.8865, 0.7619, 0.9352, 0.8091, 0, 56522]
# ['737E_Security_Cam', 'mirai', 'gafgyt', 'DTR', 0.468, 0.6147, 0.6839, 0.4555, 0, 208694]
# ['838_Security_Cam', 'gafgyt', 'mirai', 'DTR', 0.8877, 0.8122, 0.931, 0.8473, 0, 59277]
# ['838_Security_Cam', 'mirai', 'gafgyt', 'DTR', 0.5157, 0.6665, 0.6806, 0.5152, 0, 197390]
# ['1002_Security_Cam', 'gafgyt', 'mirai', 'DTR', 0.9995, 0.9971, 0.9997, 0.9984, 0, 272]
# ['1002_Security_Cam', 'mirai', 'gafgyt', 'DTR', 0.4496, 0.5974, 0.6825, 0.4305, 0, 192544]
# ['1003_Security_Cam', 'gafgyt', 'mirai', 'DTR', 0.8256, 0.5866, 0.9095, 0.5979, 0, 93203]
# ['1003_Security_Cam', 'mirai', 'gafgyt', 'DTR', 0.3987, 0.5441, 0.6808, 0.3466, 0, 202008]
# ['Danmini_Doorbell', 'gafgyt', 'mirai', 'ADB', 1.0, 1.0, 1.0, 1.0, 0, 3]
# ['Danmini_Doorbell', 'mirai', 'gafgyt', 'ADB', 0.4546, 0.5994, 0.6846, 0.4355, 0, 199734]
# ['Ecobee_Thermostat', 'gafgyt', 'mirai', 'ADB', 0.9209, 0.62, 0.9595, 0.6724, 0, 41527]
# ['Ecobee_Thermostat', 'mirai', 'gafgyt', 'ADB', 0.382, 0.5308, 0.678, 0.3204, 0, 200069]
# ['Philips_Baby_Monitor', 'gafgyt', 'mirai', 'ADB', 0.7804, 0.7519, 0.8587, 0.7527, 0, 172609]
# ['Philips_Baby_Monitor', 'mirai', 'gafgyt', 'ADB', 0.5366, 0.7183, 0.6385, 0.5208, 0, 226115]
# ['737E_Security_Cam', 'gafgyt', 'mirai', 'ADB', 0.9943, 0.978, 0.9967, 0.9871, 0, 2855]
# ['737E_Security_Cam', 'mirai', 'gafgyt', 'ADB', 0.4678, 0.6147, 0.6838, 0.4554, 0, 208741]
# ['838_Security_Cam', 'gafgyt', 'mirai', 'ADB', 0.9933, 0.9828, 0.9959, 0.9892, 0, 3518]
# ['838_Security_Cam', 'mirai', 'gafgyt', 'ADB', 0.5235, 0.6683, 0.6858, 0.5227, 0, 194202]
# ['1002_Security_Cam', 'gafgyt', 'mirai', 'ADB', 0.6342, 0.5927, 0.8005, 0.5317, 0, 204794]
# ['1002_Security_Cam', 'mirai', 'gafgyt', 'ADB', 0.4216, 0.5936, 0.6664, 0.4073, 0, 202340]
# ['1003_Security_Cam', 'gafgyt', 'mirai', 'ADB', 1.0, 0.9998, 1.0, 0.9999, 0, 7]
# ['1003_Security_Cam', 'mirai', 'gafgyt', 'ADB', 0.3991, 0.5441, 0.681, 0.3468, 0, 201893]

# %%
res_df =pd.DataFrame(all_results, index=None)

res_df, res_df.columns = res_df[1:] , res_df.iloc[0]

res_df
# Out:
# 0                 DEVICE TRAIN-BOTNET TEST-BOTNET CLASSIFIER ACCURACY  \
# 1       Danmini_Doorbell       gafgyt       mirai        KNN   0.5817
# 2       Danmini_Doorbell        mirai      gafgyt        KNN   0.3731
# 3      Ecobee_Thermostat       gafgyt       mirai        KNN   0.5533
# 4      Ecobee_Thermostat        mirai      gafgyt        KNN   0.3516
# 5   Philips_Baby_Monitor       gafgyt       mirai        KNN   0.5988
# 6   Philips_Baby_Monitor        mirai      gafgyt        KNN   0.5291
# 7      737E_Security_Cam       gafgyt       mirai        KNN   0.6729
# 8      737E_Security_Cam        mirai      gafgyt        KNN   0.4402
# 9       838_Security_Cam       gafgyt       mirai        KNN   0.6655
# 10      838_Security_Cam        mirai      gafgyt        KNN   0.4753
# 11     1002_Security_Cam       gafgyt       mirai        KNN   0.4983
# 12     1002_Security_Cam        mirai      gafgyt        KNN   0.3926
# 13     1003_Security_Cam       gafgyt       mirai        KNN   0.4892
# 14     1003_Security_Cam        mirai      gafgyt        KNN   0.3693
# 15      Danmini_Doorbell       gafgyt       mirai        RFR      1.0
# 16      Danmini_Doorbell        mirai      gafgyt        RFR   0.4572
# 17     Ecobee_Thermostat       gafgyt       mirai        RFR      1.0
# 18     Ecobee_Thermostat        mirai      gafgyt        RFR   0.3825
# 19  Philips_Baby_Monitor       gafgyt       mirai        RFR   0.9049
# 20  Philips_Baby_Monitor        mirai      gafgyt        RFR   0.5805
# 21     737E_Security_Cam       gafgyt       mirai        RFR      1.0
# 22     737E_Security_Cam        mirai      gafgyt        RFR   0.4678
# 23      838_Security_Cam       gafgyt       mirai        RFR   0.9938
# 24      838_Security_Cam        mirai      gafgyt        RFR   0.5165
# 25     1002_Security_Cam       gafgyt       mirai        RFR   0.9999
# 26     1002_Security_Cam        mirai      gafgyt        RFR   0.4479
# 27     1003_Security_Cam       gafgyt       mirai        RFR    0.952
# 28     1003_Security_Cam        mirai      gafgyt        RFR   0.4015
# 29      Danmini_Doorbell       gafgyt       mirai        DTR   0.9945
# 30      Danmini_Doorbell        mirai      gafgyt        DTR   0.4562
# 31     Ecobee_Thermostat       gafgyt       mirai        DTR   0.9626
# 32     Ecobee_Thermostat        mirai      gafgyt        DTR   0.3821
# 33  Philips_Baby_Monitor       gafgyt       mirai        DTR   0.9519
# 34  Philips_Baby_Monitor        mirai      gafgyt        DTR   0.5366
# 35     737E_Security_Cam       gafgyt       mirai        DTR   0.8865
# 36     737E_Security_Cam        mirai      gafgyt        DTR    0.468
# 37      838_Security_Cam       gafgyt       mirai        DTR   0.8877
# 38      838_Security_Cam        mirai      gafgyt        DTR   0.5157
# 39     1002_Security_Cam       gafgyt       mirai        DTR   0.9995
# 40     1002_Security_Cam        mirai      gafgyt        DTR   0.4496
# 41     1003_Security_Cam       gafgyt       mirai        DTR   0.8256
# 42     1003_Security_Cam        mirai      gafgyt        DTR   0.3987
# 43      Danmini_Doorbell       gafgyt       mirai        ADB      1.0
# 44      Danmini_Doorbell        mirai      gafgyt        ADB   0.4546
# 45     Ecobee_Thermostat       gafgyt       mirai        ADB   0.9209
# 46     Ecobee_Thermostat        mirai      gafgyt        ADB    0.382
# 47  Philips_Baby_Monitor       gafgyt       mirai        ADB   0.7804
# 48  Philips_Baby_Monitor        mirai      gafgyt        ADB   0.5366
# 49     737E_Security_Cam       gafgyt       mirai        ADB   0.9943
# 50     737E_Security_Cam        mirai      gafgyt        ADB   0.4678
# 51      838_Security_Cam       gafgyt       mirai        ADB   0.9933
# 52      838_Security_Cam        mirai      gafgyt        ADB   0.5235
# 53     1002_Security_Cam       gafgyt       mirai        ADB   0.6342
# 54     1002_Security_Cam        mirai      gafgyt        ADB   0.4216
# 55     1003_Security_Cam       gafgyt       mirai        ADB      1.0
# 56     1003_Security_Cam        mirai      gafgyt        ADB   0.3991
#
# 0  PRECISION  RECALL F1-SCORE FALSE-P FALSE-N
# 1     0.5719  0.7739   0.4808     113  293376
# 2     0.5873  0.6357   0.3663     212  229368
# 3     0.5256  0.7625    0.401     227  234425
# 4     0.5278  0.6536   0.2998     234  209684
# 5     0.6785  0.7417   0.5892      55  315246
# 6     0.6987  0.6288    0.514    3044  226720
# 7     0.6377  0.8124   0.6013     115  162822
# 8      0.607  0.6634   0.4311     613  218958
# 9     0.6784  0.7934    0.634     246  176339
# 10    0.6514  0.6502   0.4753    1102  212744
# 11    0.5708  0.7253   0.4361     110  280732
# 12    0.5877  0.6467   0.3825     322  212156
# 13    0.5332  0.7336   0.3821      55  272895
# 14    0.5414  0.6623   0.3259     121  211759
# 15       1.0     1.0      1.0       0       0
# 16    0.5998  0.6861   0.4376       0  198780
# 17    0.9991     1.0   0.9995       0      24
# 18    0.5308  0.6782   0.3208       0  199909
# 19    0.8505  0.9388   0.8795       0   74724
# 20    0.7306  0.6727   0.5723       0  204723
# 21       1.0     1.0      1.0       0       4
# 22    0.6147  0.6838   0.4554       0  208751
# 23    0.9838  0.9962   0.9899       0    3292
# 24    0.6667  0.6812    0.516       0  197036
# 25    0.9995     1.0   0.9997       0      50
# 26    0.5972  0.6815   0.4291       0  193124
# 27    0.7162  0.9751   0.7891       0   25634
# 28    0.5443  0.6823   0.3485       0  201066
# 29    0.9641  0.9971   0.9799       0    3829
# 30    0.5996  0.6855   0.4368       0  199147
# 31    0.7001  0.9808    0.776       0   19653
# 32    0.5308   0.678   0.3205       0  200033
# 33    0.9113  0.9691   0.9354       0   37801
# 34    0.7183  0.6385   0.5208       0  226115
# 35    0.7619  0.9352   0.8091       0   56522
# 36    0.6147  0.6839   0.4555       0  208694
# 37    0.8122   0.931   0.8473       0   59277
# 38    0.6665  0.6806   0.5152       0  197390
# 39    0.9971  0.9997   0.9984       0     272
# 40    0.5974  0.6825   0.4305       0  192544
# 41    0.5866  0.9095   0.5979       0   93203
# 42    0.5441  0.6808   0.3466       0  202008
# 43       1.0     1.0      1.0       0       3
# 44    0.5994  0.6846   0.4355       0  199734
# 45      0.62  0.9595   0.6724       0   41527
# 46    0.5308   0.678   0.3204       0  200069
# 47    0.7519  0.8587   0.7527       0  172609
# 48    0.7183  0.6385   0.5208       0  226115
# 49     0.978  0.9967   0.9871       0    2855
# 50    0.6147  0.6838   0.4554       0  208741
# 51    0.9828  0.9959   0.9892       0    3518
# 52    0.6683  0.6858   0.5227       0  194202
# 53    0.5927  0.8005   0.5317       0  204794
# 54    0.5936  0.6664   0.4073       0  202340
# 55    0.9998     1.0   0.9999       0       7
# 56    0.5441   0.681   0.3468       0  201893

# %%
# Write to csv
res_csv = res_df.to_csv(index=False)

print(res_csv, file=open('05_results.csv', 'w'))

# %% [markdown]
# ### Load results from CSV

# %%
res_df = pd.read_csv('05_results.csv')

#res_df = res_df[['DEVICE', 'BOTNET', 'CLASSIFIER', 'ACCURACY', 'PRECISION', 'FALSE-P', 'FALSE-N' ]]

res_df
# Out:
#                   DEVICE TRAIN-BOTNET TEST-BOTNET CLASSIFIER  ACCURACY  \
# 0       Danmini_Doorbell       gafgyt       mirai        KNN    0.5817
# 1       Danmini_Doorbell        mirai      gafgyt        KNN    0.3731
# 2      Ecobee_Thermostat       gafgyt       mirai        KNN    0.5533
# 3      Ecobee_Thermostat        mirai      gafgyt        KNN    0.3516
# 4   Philips_Baby_Monitor       gafgyt       mirai        KNN    0.5988
# 5   Philips_Baby_Monitor        mirai      gafgyt        KNN    0.5291
# 6      737E_Security_Cam       gafgyt       mirai        KNN    0.6729
# 7      737E_Security_Cam        mirai      gafgyt        KNN    0.4402
# 8       838_Security_Cam       gafgyt       mirai        KNN    0.6655
# 9       838_Security_Cam        mirai      gafgyt        KNN    0.4753
# 10     1002_Security_Cam       gafgyt       mirai        KNN    0.4983
# 11     1002_Security_Cam        mirai      gafgyt        KNN    0.3926
# 12     1003_Security_Cam       gafgyt       mirai        KNN    0.4892
# 13     1003_Security_Cam        mirai      gafgyt        KNN    0.3693
# 14      Danmini_Doorbell       gafgyt       mirai        RFR    1.0000
# 15      Danmini_Doorbell        mirai      gafgyt        RFR    0.4572
# 16     Ecobee_Thermostat       gafgyt       mirai        RFR    1.0000
# 17     Ecobee_Thermostat        mirai      gafgyt        RFR    0.3825
# 18  Philips_Baby_Monitor       gafgyt       mirai        RFR    0.9049
# 19  Philips_Baby_Monitor        mirai      gafgyt        RFR    0.5805
# 20     737E_Security_Cam       gafgyt       mirai        RFR    1.0000
# 21     737E_Security_Cam        mirai      gafgyt        RFR    0.4678
# 22      838_Security_Cam       gafgyt       mirai        RFR    0.9938
# 23      838_Security_Cam        mirai      gafgyt        RFR    0.5165
# 24     1002_Security_Cam       gafgyt       mirai        RFR    0.9999
# 25     1002_Security_Cam        mirai      gafgyt        RFR    0.4479
# 26     1003_Security_Cam       gafgyt       mirai        RFR    0.9520
# 27     1003_Security_Cam        mirai      gafgyt        RFR    0.4015
# 28      Danmini_Doorbell       gafgyt       mirai        DTR    0.9945
# 29      Danmini_Doorbell        mirai      gafgyt        DTR    0.4562
# 30     Ecobee_Thermostat       gafgyt       mirai        DTR    0.9626
# 31     Ecobee_Thermostat        mirai      gafgyt        DTR    0.3821
# 32  Philips_Baby_Monitor       gafgyt       mirai        DTR    0.9519
# 33  Philips_Baby_Monitor        mirai      gafgyt        DTR    0.5366
# 34     737E_Security_Cam       gafgyt       mirai        DTR    0.8865
# 35     737E_Security_Cam        mirai      gafgyt        DTR    0.4680
# 36      838_Security_Cam       gafgyt       mirai        DTR    0.8877
# 37      838_Security_Cam        mirai      gafgyt        DTR    0.5157
# 38     1002_Security_Cam       gafgyt       mirai        DTR    0.9995
# 39     1002_Security_Cam        mirai      gafgyt        DTR    0.4496
# 40     1003_Security_Cam       gafgyt       mirai        DTR    0.8256
# 41     1003_Security_Cam        mirai      gafgyt        DTR    0.3987
# 42      Danmini_Doorbell       gafgyt       mirai        ADB    1.0000
# 43      Danmini_Doorbell        mirai      gafgyt        ADB    0.4546
# 44     Ecobee_Thermostat       gafgyt       mirai        ADB    0.9209
# 45     Ecobee_Thermostat        mirai      gafgyt        ADB    0.3820
# 46  Philips_Baby_Monitor       gafgyt       mirai        ADB    0.7804
# 47  Philips_Baby_Monitor        mirai      gafgyt        ADB    0.5366
# 48     737E_Security_Cam       gafgyt       mirai        ADB    0.9943
# 49     737E_Security_Cam        mirai      gafgyt        ADB    0.4678
# 50      838_Security_Cam       gafgyt       mirai        ADB    0.9933
# 51      838_Security_Cam        mirai      gafgyt        ADB    0.5235
# 52     1002_Security_Cam       gafgyt       mirai        ADB    0.6342
# 53     1002_Security_Cam        mirai      gafgyt        ADB    0.4216
# 54     1003_Security_Cam       gafgyt       mirai        ADB    1.0000
# 55     1003_Security_Cam        mirai      gafgyt        ADB    0.3991
#
#     PRECISION  RECALL  F1-SCORE  FALSE-P  FALSE-N
# 0      0.5719  0.7739    0.4808      113   293376
# 1      0.5873  0.6357    0.3663      212   229368
# 2      0.5256  0.7625    0.4010      227   234425
# 3      0.5278  0.6536    0.2998      234   209684
# 4      0.6785  0.7417    0.5892       55   315246
# 5      0.6987  0.6288    0.5140     3044   226720
# 6      0.6377  0.8124    0.6013      115   162822
# 7      0.6070  0.6634    0.4311      613   218958
# 8      0.6784  0.7934    0.6340      246   176339
# 9      0.6514  0.6502    0.4753     1102   212744
# 10     0.5708  0.7253    0.4361      110   280732
# 11     0.5877  0.6467    0.3825      322   212156
# 12     0.5332  0.7336    0.3821       55   272895
# 13     0.5414  0.6623    0.3259      121   211759
# 14     1.0000  1.0000    1.0000        0        0
# 15     0.5998  0.6861    0.4376        0   198780
# 16     0.9991  1.0000    0.9995        0       24
# 17     0.5308  0.6782    0.3208        0   199909
# 18     0.8505  0.9388    0.8795        0    74724
# 19     0.7306  0.6727    0.5723        0   204723
# 20     1.0000  1.0000    1.0000        0        4
# 21     0.6147  0.6838    0.4554        0   208751
# 22     0.9838  0.9962    0.9899        0     3292
# 23     0.6667  0.6812    0.5160        0   197036
# 24     0.9995  1.0000    0.9997        0       50
# 25     0.5972  0.6815    0.4291        0   193124
# 26     0.7162  0.9751    0.7891        0    25634
# 27     0.5443  0.6823    0.3485        0   201066
# 28     0.9641  0.9971    0.9799        0     3829
# 29     0.5996  0.6855    0.4368        0   199147
# 30     0.7001  0.9808    0.7760        0    19653
# 31     0.5308  0.6780    0.3205        0   200033
# 32     0.9113  0.9691    0.9354        0    37801
# 33     0.7183  0.6385    0.5208        0   226115
# 34     0.7619  0.9352    0.8091        0    56522
# 35     0.6147  0.6839    0.4555        0   208694
# 36     0.8122  0.9310    0.8473        0    59277
# 37     0.6665  0.6806    0.5152        0   197390
# 38     0.9971  0.9997    0.9984        0      272
# 39     0.5974  0.6825    0.4305        0   192544
# 40     0.5866  0.9095    0.5979        0    93203
# 41     0.5441  0.6808    0.3466        0   202008
# 42     1.0000  1.0000    1.0000        0        3
# 43     0.5994  0.6846    0.4355        0   199734
# 44     0.6200  0.9595    0.6724        0    41527
# 45     0.5308  0.6780    0.3204        0   200069
# 46     0.7519  0.8587    0.7527        0   172609
# 47     0.7183  0.6385    0.5208        0   226115
# 48     0.9780  0.9967    0.9871        0     2855
# 49     0.6147  0.6838    0.4554        0   208741
# 50     0.9828  0.9959    0.9892        0     3518
# 51     0.6683  0.6858    0.5227        0   194202
# 52     0.5927  0.8005    0.5317        0   204794
# 53     0.5936  0.6664    0.4073        0   202340
# 54     0.9998  1.0000    0.9999        0        7
# 55     0.5441  0.6810    0.3468        0   201893

# %%
#do classification report

# %%
pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import classification_report
from tabulate import tabulate

# Load results from CSV
res_df = pd.read_csv('05_results.csv')

# Filter the relevant columns
filtered_df = res_df[['TEST-BOTNET', 'CLASSIFIER', 'ACCURACY', 'PRECISION', 'RECALL', 'F1-SCORE', 'FALSE-P', 'FALSE-N']]

# Group the data by botnet and classifier
grouped = filtered_df.groupby(['TEST-BOTNET', 'CLASSIFIER'])

# Store classification report results in a list
classification_reports = []

# Iterate through the grouped data and generate classification report
for (botnet, clf), group in grouped:
    avg_accuracy = group['ACCURACY'].mean()
    avg_precision = group['PRECISION'].mean()
    avg_recall = group['RECALL'].mean()
    avg_f1_score = group['F1-SCORE'].mean()
    avg_false_positive = group['FALSE-P'].mean()
    avg_false_negative = group['FALSE-N'].mean()

    report = f"Botnet: {botnet}, Classifier: {clf}\n"
    report += tabulate(
        [[avg_accuracy, avg_precision, avg_recall, avg_f1_score, avg_false_positive, avg_false_negative]],
        headers=['Accuracy', 'Precision', 'Recall', 'F1-Score', 'False Positives', 'False Negatives'],
        tablefmt='grid'
    )
    classification_reports.append(report)

# Print the classification reports
for report in classification_reports:
    print(report)
    print("\n\n")
# Out:
# Botnet: gafgyt, Classifier: ADB
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |   0.455029 |    0.609886 | 0.674014 |   0.429843 |                 0 |            204728 |
# +------------+-------------+----------+------------+-------------------+-------------------+
#
#
#
# Botnet: gafgyt, Classifier: DTR
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |   0.458129 |      0.6102 | 0.675686 |   0.432271 |                 0 |            203704 |
# +------------+-------------+----------+------------+-------------------+-------------------+
#
#
#
# Botnet: gafgyt, Classifier: KNN
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |   0.418743 |    0.600186 | 0.648671 |   0.399271 |           806.857 |            217341 |
# +------------+-------------+----------+------------+-------------------+-------------------+
#
#
#
# Botnet: gafgyt, Classifier: RFR
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |   0.464843 |    0.612014 | 0.680829 |   0.439957 |                 0 |            200484 |
# +------------+-------------+----------+------------+-------------------+-------------------+
#
#
#
# Botnet: mirai, Classifier: ADB
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |     0.9033 |    0.846457 | 0.944471 |   0.847571 |                 0 |             60759 |
# +------------+-------------+----------+------------+-------------------+-------------------+
#
#
#
# Botnet: mirai, Classifier: DTR
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |   0.929757 |    0.819043 | 0.960343 |   0.849143 |                 0 |             38651 |
# +------------+-------------+----------+------------+-------------------+-------------------+
#
#
#
# Botnet: mirai, Classifier: KNN
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |   0.579957 |    0.599443 | 0.763257 |     0.5035 |           131.571 |            247976 |
# +------------+-------------+----------+------------+-------------------+-------------------+
#
#
#
# Botnet: mirai, Classifier: RFR
# +------------+-------------+----------+------------+-------------------+-------------------+
# |   Accuracy |   Precision |   Recall |   F1-Score |   False Positives |   False Negatives |
# +============+=============+==========+============+===================+===================+
# |   0.978657 |    0.935586 | 0.987157 |     0.9511 |                 0 |           14818.3 |
# +------------+-------------+----------+------------+-------------------+-------------------+

# %%
# Load results from CSV
res_df = pd.read_csv('05_results.csv')

# Filter the relevant columns
filtered_df = res_df[['TEST-BOTNET', 'CLASSIFIER', 'ACCURACY', 'PRECISION', 'RECALL', 'F1-SCORE', 'FALSE-P', 'FALSE-N']]

# Group the data by botnet and classifier
grouped = filtered_df.groupby(['TEST-BOTNET', 'CLASSIFIER'])

# Store classification report results in a dictionary for each botnet
botnet_reports = {}

# Iterate through the grouped data and generate classification reports
for (botnet, clf), group in grouped:
    avg_metrics = group.mean()
    metrics_names = ['ACCURACY', 'PRECISION', 'RECALL', 'F1-SCORE', 'FALSE-P', 'FALSE-N']
    avg_values = avg_metrics[metrics_names].values

    if botnet not in botnet_reports:
        botnet_reports[botnet] = []

    botnet_reports[botnet].append([clf] + avg_values.tolist())

# Print the classification reports for each botnet
for botnet, reports in botnet_reports.items():
    headers = ['CLASSIFIER'] + metrics_names
    table = tabulate(reports, headers=headers, tablefmt='grid')
    
    print(f"Botnet: {botnet}")
    print(table)
    print("\n")
# Out:
# Botnet: gafgyt
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | CLASSIFIER   |   ACCURACY |   PRECISION |   RECALL |   F1-SCORE |   FALSE-P |   FALSE-N |
# +==============+============+=============+==========+============+===========+===========+
# | ADB          |   0.455029 |    0.609886 | 0.674014 |   0.429843 |     0     |    204728 |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | DTR          |   0.458129 |    0.6102   | 0.675686 |   0.432271 |     0     |    203704 |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | KNN          |   0.418743 |    0.600186 | 0.648671 |   0.399271 |   806.857 |    217341 |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | RFR          |   0.464843 |    0.612014 | 0.680829 |   0.439957 |     0     |    200484 |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
#
#
# Botnet: mirai
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | CLASSIFIER   |   ACCURACY |   PRECISION |   RECALL |   F1-SCORE |   FALSE-P |   FALSE-N |
# +==============+============+=============+==========+============+===========+===========+
# | ADB          |   0.9033   |    0.846457 | 0.944471 |   0.847571 |     0     |   60759   |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | DTR          |   0.929757 |    0.819043 | 0.960343 |   0.849143 |     0     |   38651   |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | KNN          |   0.579957 |    0.599443 | 0.763257 |   0.5035   |   131.571 |  247976   |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# | RFR          |   0.978657 |    0.935586 | 0.987157 |   0.9511   |     0     |   14818.3 |
# +--------------+------------+-------------+----------+------------+-----------+-----------+
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
# C:\Users\jessm\AppData\Local\Temp\ipykernel_24216\1550177976.py:15: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg_metrics = group.mean()
